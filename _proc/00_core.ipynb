# %% [raw]
# ---
# description: The building blocks to the UI
# output-file: core.html
# title: Core
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## Imports

# %%
from nbdev.showdoc import show_doc
from IPython.display import HTML

# %% [markdown]
# ## Utils

# %% [markdown]
# ### Tests

# %%
from fastcore.test import *

# %%
def test_xml_eq(a, b):
    "Tests if if 2 FT components generate the same xml"
    test_eq(*map(lambda x: x if isinstance(x,str) else to_xml(x), (a, b)))

# %% [markdown]
# ### Other

# %%
#| echo: false
#| output: asis
show_doc(stringify)
# Out:
# ---
#
# [source](https://github.com/Isaac-Flath/fh-frankenui/blob/main/fh_frankenui/core.py#L26){target="_blank" style="float:right; font-size:smaller"}
#
# ### stringify
#
# >      stringify (o)
#
# *Converts input types into strings that can be passed to FT components*
#
# |    | **Details** |
# | -- | ----------- |
# | o | String, Tuple, or Enum options we want stringified |

# %%
assert stringify('abc') == 'abc'
assert stringify(('abc','def')) == 'abc def'
assert 'uk-input ' + stringify(()) == 'uk-input '
assert 'uk-input ' + stringify("") == 'uk-input '

# %%
#| echo: false
#| output: asis
show_doc(VEnum)
# Out:
# ---
#
# [source](https://github.com/Isaac-Flath/fh-frankenui/blob/main/fh_frankenui/core.py#L33){target="_blank" style="float:right; font-size:smaller"}
#
# ### VEnum
#
# >      VEnum (new_class_name, names, module=None, qualname=None, type=None,
# >             start=1, boundary=None)
#
# *Create a collection of name/value pairs.
#
# Example enumeration:
#
# >>> class Color(Enum):
# ...     RED = 1
# ...     BLUE = 2
# ...     GREEN = 3
#
# Access them by:
#
# - attribute access:
#
#   >>> Color.RED
#   <Color.RED: 1>
#
# - value lookup:
#
#   >>> Color(1)
#   <Color.RED: 1>
#
# - name lookup:
#
#   >>> Color['RED']
#   <Color.RED: 1>
#
# Enumerations can be iterated over, and know how many members they have:
#
# >>> len(Color)
# 3
#
# >>> list(Color)
# [<Color.RED: 1>, <Color.BLUE: 2>, <Color.GREEN: 3>]
#
# Methods can be added to enumerations, and members can have their own
# attributes -- see the documentation for details.*

# %% [markdown]
# ## Enums

# %% [markdown]
# ### Theme

# %% [markdown]
# You can select a theme color to and get all the headers.  This brings in the most standard grouping:
# + Tailwind: Optional, but typically FrankenUI is used in conjunction with tailwind
# + Uikit: Many things are styled with uikit
# + UIkit icons: Gives many icons OOTB, and is nice to have handy.
# + Franken WC: Neccesarry for some of the (minimal) interactivity components have

# %%
#| echo: false
#| output: asis
show_doc(Theme)
# Out:
# ---
#
# [source](https://github.com/Isaac-Flath/fh-frankenui/blob/main/fh_frankenui/core.py#L50){target="_blank" style="float:right; font-size:smaller"}
#
# ### Theme
#
# >      Theme (*values)
#
# *Create a collection of name/value pairs.
#
# Example enumeration:
#
# >>> class Color(Enum):
# ...     RED = 1
# ...     BLUE = 2
# ...     GREEN = 3
#
# Access them by:
#
# - attribute access:
#
#   >>> Color.RED
#   <Color.RED: 1>
#
# - value lookup:
#
#   >>> Color(1)
#   <Color.RED: 1>
#
# - name lookup:
#
#   >>> Color['RED']
#   <Color.RED: 1>
#
# Enumerations can be iterated over, and know how many members they have:
#
# >>> len(Color)
# 3
#
# >>> list(Color)
# [<Color.RED: 1>, <Color.BLUE: 2>, <Color.GREEN: 3>]
#
# Methods can be added to enumerations, and members can have their own
# attributes -- see the documentation for details.*

# %%
hdrs = Theme.blue.headers()
app = FastHTML(hdrs=hdrs)
hdrs
# Out:
# (script(('',),{'src': 'https://cdn.tailwindcss.com'}),
#  script(('',),{'src': 'https://cdn.jsdelivr.net/npm/uikit@3.21.6/dist/js/uikit.min.js'}),
#  script(('',),{'src': 'https://cdn.jsdelivr.net/npm/uikit@3.21.6/dist/js/uikit-icons.min.js'}),
#  script(('',),{'type': 'module', 'src': 'https://unpkg.com/franken-wc@0.0.6/dist/js/wc.iife.js'}),
#  link((),{'rel': 'stylesheet', 'href': 'https://unpkg.com/franken-wc@0.0.6/dist/css/blue.min.css'}))

# %% [markdown]
# ### Style

# %% [markdown]
# #### `B` (Base)

# %% [markdown]
# Base enums all will end with `B`.  These are designed to make classes discoverable in python.  These should be generally a 1:1 mapping to a class.
#
# These are the lowest level class selection options without dropping into strings.  We don't need to cover everything, but we want most useful things in here.

# %%
#| echo: false
#| output: asis
show_doc(TextB)
# Out:
# ---
#
# [source](https://github.com/Isaac-Flath/fh-frankenui/blob/main/fh_frankenui/core.py#L74){target="_blank" style="float:right; font-size:smaller"}
#
# ### TextB
#
# >      TextB (*values)
#
# *Create a collection of name/value pairs.
#
# Example enumeration:
#
# >>> class Color(Enum):
# ...     RED = 1
# ...     BLUE = 2
# ...     GREEN = 3
#
# Access them by:
#
# - attribute access:
#
#   >>> Color.RED
#   <Color.RED: 1>
#
# - value lookup:
#
#   >>> Color(1)
#   <Color.RED: 1>
#
# - name lookup:
#
#   >>> Color['RED']
#   <Color.RED: 1>
#
# Enumerations can be iterated over, and know how many members they have:
#
# >>> len(Color)
# 3
#
# >>> list(Color)
# [<Color.RED: 1>, <Color.BLUE: 2>, <Color.GREEN: 3>]
#
# Methods can be added to enumerations, and members can have their own
# attributes -- see the documentation for details.*

# %% [markdown]
# ### `T` (Transform)

# %% [markdown]
# Transform enums all will end with `T`.  These are designed to make useful class groups discoverable in python.
#
# Each option should be a group of enums that are useful in many cases.  For example `muted_sm` is very commonly used as a subheader below a card title and looks great.  These should be high level things that users can generally just pick from to have a decent default without much thought.

# %%
#| echo: false
#| output: asis
show_doc(TextT)
# Out:
# ---
#
# [source](https://github.com/Isaac-Flath/fh-frankenui/blob/main/fh_frankenui/core.py#L101){target="_blank" style="float:right; font-size:smaller"}
#
# ### TextT
#
# >      TextT (*values)
#
# *Create a collection of name/value pairs.
#
# Example enumeration:
#
# >>> class Color(Enum):
# ...     RED = 1
# ...     BLUE = 2
# ...     GREEN = 3
#
# Access them by:
#
# - attribute access:
#
#   >>> Color.RED
#   <Color.RED: 1>
#
# - value lookup:
#
#   >>> Color(1)
#   <Color.RED: 1>
#
# - name lookup:
#
#   >>> Color['RED']
#   <Color.RED: 1>
#
# Enumerations can be iterated over, and know how many members they have:
#
# >>> len(Color)
# 3
#
# >>> list(Color)
# [<Color.RED: 1>, <Color.BLUE: 2>, <Color.GREEN: 3>]
#
# Methods can be added to enumerations, and members can have their own
# attributes -- see the documentation for details.*

# %%
type(TextT.muted_sm)
# Out:
# <enum 'TextT'>

# %% [markdown]
# ## Base Components

# %% [markdown]
# ### Icons and Avatars

# %%
#| echo: false
#| output: asis
show_doc(UkIcon)
# Out:
# ---
#
# [source](https://github.com/Isaac-Flath/fh-frankenui/blob/main/fh_frankenui/core.py#L114){target="_blank" style="float:right; font-size:smaller"}
#
# ### UkIcon
#
# >      UkIcon (icon, ratio=1, cls=())

# %%
#| echo: false
#| output: asis
show_doc(DiceBearAvatar)
# Out:
# ---
#
# [source](https://github.com/Isaac-Flath/fh-frankenui/blob/main/fh_frankenui/core.py#L118){target="_blank" style="float:right; font-size:smaller"}
#
# ### DiceBearAvatar
#
# >      DiceBearAvatar (seed_name, h, w)

# %% [markdown]
# ### Spacing

# %%
#| echo: false
#| output: asis
show_doc(FlexT)
# Out:
# ---
#
# ### FlexT
#
# >      FlexT (*values)
#
# *Create a collection of name/value pairs.
#
# Example enumeration:
#
# >>> class Color(Enum):
# ...     RED = 1
# ...     BLUE = 2
# ...     GREEN = 3
#
# Access them by:
#
# - attribute access:
#
#   >>> Color.RED
#   <Color.RED: 1>
#
# - value lookup:
#
#   >>> Color(1)
#   <Color.RED: 1>
#
# - name lookup:
#
#   >>> Color['RED']
#   <Color.RED: 1>
#
# Enumerations can be iterated over, and know how many members they have:
#
# >>> len(Color)
# 3
#
# >>> list(Color)
# [<Color.RED: 1>, <Color.BLUE: 2>, <Color.GREEN: 3>]
#
# Methods can be added to enumerations, and members can have their own
# attributes -- see the documentation for details.*

# %%
Div(cls=FlexT.block+FlexT.left+FlexT.middle+' some_cls')
# Out:
# div((),{'class': 'uk-flex uk-flex-left uk-flex-middle some_cls'})

# %%
#| echo: false
#| output: asis
show_doc(GridT)
# Out:
# ---
#
# ### GridT
#
# >      GridT (*values)
#
# *Create a collection of name/value pairs.
#
# Example enumeration:
#
# >>> class Color(Enum):
# ...     RED = 1
# ...     BLUE = 2
# ...     GREEN = 3
#
# Access them by:
#
# - attribute access:
#
#   >>> Color.RED
#   <Color.RED: 1>
#
# - value lookup:
#
#   >>> Color(1)
#   <Color.RED: 1>
#
# - name lookup:
#
#   >>> Color['RED']
#   <Color.RED: 1>
#
# Enumerations can be iterated over, and know how many members they have:
#
# >>> len(Color)
# 3
#
# >>> list(Color)
# [<Color.RED: 1>, <Color.BLUE: 2>, <Color.GREEN: 3>]
#
# Methods can be added to enumerations, and members can have their own
# attributes -- see the documentation for details.*

# %%
#| echo: false
#| output: asis
show_doc(Grid)
# Out:
# ---
#
# [source](https://github.com/Isaac-Flath/fh-frankenui/blob/main/fh_frankenui/core.py#L156){target="_blank" style="float:right; font-size:smaller"}
#
# ### Grid
#
# >      Grid (*c, cols=3, cls=(), **kwargs)

# %%
#| echo: false
#| output: asis
show_doc(ResponsiveGrid)
# Out:
# ---
#
# [source](https://github.com/Isaac-Flath/fh-frankenui/blob/main/fh_frankenui/core.py#L161){target="_blank" style="float:right; font-size:smaller"}
#
# ### ResponsiveGrid
#
# >      ResponsiveGrid (*c, sm=1, md=2, lg=3, xl=4, gap=2, cls='', **kwargs)

# %%
#| echo: false
#| output: asis
show_doc(FullySpacedDiv)
# Out:
# ---
#
# [source](https://github.com/Isaac-Flath/fh-frankenui/blob/main/fh_frankenui/core.py#L165){target="_blank" style="float:right; font-size:smaller"}
#
# ### FullySpacedDiv
#
# >      FullySpacedDiv (*c, wrap_tag=None, cls='', **kwargs)

# %%
#| echo: false
#| output: asis
show_doc(CenteredDiv)
# Out:
# ---
#
# [source](https://github.com/Isaac-Flath/fh-frankenui/blob/main/fh_frankenui/core.py#L171){target="_blank" style="float:right; font-size:smaller"}
#
# ### CenteredDiv
#
# >      CenteredDiv (*c, cls=(), **kwargs)

# %%
#| echo: false
#| output: asis
show_doc(LAlignedDiv)
# Out:
# ---
#
# [source](https://github.com/Isaac-Flath/fh-frankenui/blob/main/fh_frankenui/core.py#L176){target="_blank" style="float:right; font-size:smaller"}
#
# ### LAlignedDiv
#
# >      LAlignedDiv (*c, cls='', **kwargs)

# %%
#| echo: false
#| output: asis
show_doc(RAlignedDiv)
# Out:
# ---
#
# [source](https://github.com/Isaac-Flath/fh-frankenui/blob/main/fh_frankenui/core.py#L182){target="_blank" style="float:right; font-size:smaller"}
#
# ### RAlignedDiv
#
# >      RAlignedDiv (*c, cls='', **kwargs)

# %%
#| echo: false
#| output: asis
show_doc(VStackedDiv)
# Out:
# ---
#
# [source](https://github.com/Isaac-Flath/fh-frankenui/blob/main/fh_frankenui/core.py#L188){target="_blank" style="float:right; font-size:smaller"}
#
# ### VStackedDiv
#
# >      VStackedDiv (*c, cls='', **kwargs)

# %%
#| echo: false
#| output: asis
show_doc(HStackedDiv)
# Out:
# ---
#
# [source](https://github.com/Isaac-Flath/fh-frankenui/blob/main/fh_frankenui/core.py#L194){target="_blank" style="float:right; font-size:smaller"}
#
# ### HStackedDiv
#
# >      HStackedDiv (*c, cls='', **kwargs)

# %%
#| echo: false
#| output: asis
show_doc(SpaceBetweenDiv)
# Out:
# ---
#
# ### SpaceBetweenDiv
#
# >      SpaceBetweenDiv (*c, cls='', **kwargs)

# %% [markdown]
# ### Inputs

# %%
#| echo: false
#| output: asis
show_doc(UkGenericInput)
# Out:
# ---
#
# [source](https://github.com/Isaac-Flath/fh-frankenui/blob/main/fh_frankenui/core.py#L206){target="_blank" style="float:right; font-size:smaller"}
#
# ### UkGenericInput
#
# >      UkGenericInput (input_fn:fastcore.xml.FT, label:str|fastcore.xml.FT=(),
# >                      lbl_cls:str|enum.Enum=(), inp_cls:str|enum.Enum=(),
# >                      cls:str|enum.Enum=('space-y-2',), **kwargs)
#
# *`Div(Label,Input)` component with Uk styling injected appropriately. Generally you should higher level API, such as `UKTextArea` which is created for you in this library*
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | input_fn | FT |  | FT Components that generates a user input (e.g. `TextArea`) |
# | label | str \| fastcore.xml.FT | () | String or FT component that goes in `Label` |
# | lbl_cls | str \| enum.Enum | () | Additional classes that goes in `Label` |
# | inp_cls | str \| enum.Enum | () | Additional classes that go in user input (e.g. `TextArea`) |
# | cls | str \| enum.Enum | ('space-y-2',) | Div cls |
# | kwargs |  |  |  |
# | **Returns** | **FT** |  | **FT component in structure `(Div(label,input))`** |

# %%
UkInput("MyLabel",lbl_cls=TextT.muted_sm, inp_cls='font-bold',  id='myid')
# Out:
# div((label(('MyLabel',),{'class': 'uk-form-label text-sm uk-text-muted', 'for': <built-in function id>}), input((),{'id': 'myid', 'class': 'uk-inputfont-bold', 'name': 'myid'})),{'class': 'space-y-2'})

# %%
#| echo: false
#| output: asis
show_doc(Options)
# Out:
# ---
#
# [source](https://github.com/Isaac-Flath/fh-frankenui/blob/main/fh_frankenui/core.py#L230){target="_blank" style="float:right; font-size:smaller"}
#
# ### Options
#
# >      Options (*c, selected_idx:int=None, disabled_idxs:set=None)
#
# *Generates list of `Option`s with the proper `selected_idx`*

# %%
#| echo: false
#| output: asis
show_doc(UkSelect)
# Out:
# ---
#
# [source](https://github.com/Isaac-Flath/fh-frankenui/blob/main/fh_frankenui/core.py#L238){target="_blank" style="float:right; font-size:smaller"}
#
# ### UkSelect
#
# >      UkSelect (*options, label=(), lbl_cls=(), inp_cls=(), cls=('space-y-2',),
# >                id='', name='', placeholder='', searchable=False, **kwargs)

# %%
#| echo: false
#| output: asis
show_doc(UkButtonT)
# Out:
# ---
#
# [source](https://github.com/Isaac-Flath/fh-frankenui/blob/main/fh_frankenui/core.py#L256){target="_blank" style="float:right; font-size:smaller"}
#
# ### UkButtonT
#
# >      UkButtonT (*values)
#
# *Create a collection of name/value pairs.
#
# Example enumeration:
#
# >>> class Color(Enum):
# ...     RED = 1
# ...     BLUE = 2
# ...     GREEN = 3
#
# Access them by:
#
# - attribute access:
#
#   >>> Color.RED
#   <Color.RED: 1>
#
# - value lookup:
#
#   >>> Color(1)
#   <Color.RED: 1>
#
# - name lookup:
#
#   >>> Color['RED']
#   <Color.RED: 1>
#
# Enumerations can be iterated over, and know how many members they have:
#
# >>> len(Color)
# 3
#
# >>> list(Color)
# [<Color.RED: 1>, <Color.BLUE: 2>, <Color.GREEN: 3>]
#
# Methods can be added to enumerations, and members can have their own
# attributes -- see the documentation for details.*

# %%
#| echo: false
#| output: asis
show_doc(UkDropdownButton)
# Out:
# ---
#
# [source](https://github.com/Isaac-Flath/fh-frankenui/blob/main/fh_frankenui/core.py#L274){target="_blank" style="float:right; font-size:smaller"}
#
# ### UkDropdownButton
#
# >      UkDropdownButton (*opt_grp, opt_hdrs=None, label=None,
# >                        btn_cls=<UkButtonT.default: 'default'>, cls=(),
# >                        dd_cls=(), icon='triangle-down', icon_cls='',
# >                        icon_position='right')

# %% [markdown]
# ### Other

# %%
#| echo: false
#| output: asis
show_doc(UkButton)
# Out:
# ---
#
# [source](https://github.com/Isaac-Flath/fh-frankenui/blob/main/fh_frankenui/core.py#L295){target="_blank" style="float:right; font-size:smaller"}
#
# ### UkButton
#
# >      UkButton (*c, cls=<UkButtonT.default: 'default'>, **kwargs)

# %%
#| echo: false
#| output: asis
show_doc(UkH6)
# Out:
# ---
#
# ### UkH6
#
# >      UkH6 (*c, cls=(), **kwargs)

# %%
#| echo: false
#| output: asis
show_doc(UkH5)
# Out:
# ---
#
# ### UkH5
#
# >      UkH5 (*c, cls=(), **kwargs)

# %%
#| echo: false
#| output: asis
show_doc(UkH4)
# Out:
# ---
#
# ### UkH4
#
# >      UkH4 (*c, cls=(), **kwargs)

# %%
#| echo: false
#| output: asis
show_doc(UkH3)
# Out:
# ---
#
# ### UkH3
#
# >      UkH3 (*c, cls=(), **kwargs)

# %%
#| echo: false
#| output: asis
show_doc(UkH2)
# Out:
# ---
#
# ### UkH2
#
# >      UkH2 (*c, cls=(), **kwargs)

# %%
#| echo: false
#| output: asis
show_doc(UkH1)
# Out:
# ---
#
# ### UkH1
#
# >      UkH1 (*c, cls=(), **kwargs)

# %%
#| echo: false
#| output: asis
show_doc(UkGenericComponent)
# Out:
# ---
#
# [source](https://github.com/Isaac-Flath/fh-frankenui/blob/main/fh_frankenui/core.py#L301){target="_blank" style="float:right; font-size:smaller"}
#
# ### UkGenericComponent
#
# >      UkGenericComponent (component_fn, *c, cls=(), **kwargs)

# %%
UkH1("My Uk styled header"), UkH1('My Uk styled header',cls='another-class')
# Out:
# (h1(('My Uk styled header',),{'class': 'uk-h1 '}),
#  h1(('My Uk styled header',),{'class': 'uk-h1 another-class'}))

# %%
#| echo: false
#| output: asis
show_doc(UkHLine)
# Out:
# ---
#
# [source](https://github.com/Isaac-Flath/fh-frankenui/blob/main/fh_frankenui/core.py#L320){target="_blank" style="float:right; font-size:smaller"}
#
# ### UkHLine
#
# >      UkHLine (lwidth=2, y_space=4)

# %%
#| echo: false
#| output: asis
show_doc(UkHSplit)
# Out:
# ---
#
# [source](https://github.com/Isaac-Flath/fh-frankenui/blob/main/fh_frankenui/core.py#L314){target="_blank" style="float:right; font-size:smaller"}
#
# ### UkHSplit
#
# >      UkHSplit (*c, cls=(), line_cls=(), text_cls=())

# %%
#| echo: false
#| output: asis
show_doc(UkNavDivider)
# Out:
# ---
#
# [source](https://github.com/Isaac-Flath/fh-frankenui/blob/main/fh_frankenui/core.py#L323){target="_blank" style="float:right; font-size:smaller"}
#
# ### UkNavDivider
#
# >      UkNavDivider ()

# %% [markdown]
# ## Higher order components

# %% [markdown]
# ### Navigation

# %% [markdown]
# #### Navbar

# %%
#| echo: false
#| output: asis
show_doc(UkNavbarDropdown)
# Out:
# ---
#
# [source](https://github.com/Isaac-Flath/fh-frankenui/blob/main/fh_frankenui/core.py#L326){target="_blank" style="float:right; font-size:smaller"}
#
# ### UkNavbarDropdown
#
# >      UkNavbarDropdown (*c, label, href='#', cls='', has_header=False,
# >                        **kwargs)

# %%
#| echo: false
#| output: asis
show_doc(UkNavbar)
# Out:
# ---
#
# [source](https://github.com/Isaac-Flath/fh-frankenui/blob/main/fh_frankenui/core.py#L346){target="_blank" style="float:right; font-size:smaller"}
#
# ### UkNavbar
#
# >      UkNavbar (lnav:Sequence[Union[str,fastcore.xml.FT]]=None,
# >                rnav:Sequence[Union[str,fastcore.xml.FT]]=None, cls='',
# >                **kwargs)

# %% [markdown]
# #### Navtab

# %%
#| echo: false
#| output: asis
show_doc(UkTab)
# Out:
# ---
#
# [source](https://github.com/Isaac-Flath/fh-frankenui/blob/main/fh_frankenui/core.py#L359){target="_blank" style="float:right; font-size:smaller"}
#
# ### UkTab
#
# >      UkTab (*items, maxw=96, cls='', **kwargs)

# %%
#| echo: false
#| output: asis
show_doc(NavTab)
# Out:
# ---
#
# [source](https://github.com/Isaac-Flath/fh-frankenui/blob/main/fh_frankenui/core.py#L356){target="_blank" style="float:right; font-size:smaller"}
#
# ### NavTab
#
# >      NavTab (text, active=False)

# %% [markdown]
# #### Sidebar

# %%
#| echo: false
#| output: asis
show_doc(UkSidebar)
# Out:
# ---
#
# [source](https://github.com/Isaac-Flath/fh-frankenui/blob/main/fh_frankenui/core.py#L376){target="_blank" style="float:right; font-size:smaller"}
#
# ### UkSidebar
#
# >      UkSidebar (sections, headers=None, outer_margin=4, inner_margin=4,
# >                 cls=(), **kwargs)

# %%
#| echo: false
#| output: asis
show_doc(UkSidebarSection)
# Out:
# ---
#
# [source](https://github.com/Isaac-Flath/fh-frankenui/blob/main/fh_frankenui/core.py#L370){target="_blank" style="float:right; font-size:smaller"}
#
# ### UkSidebarSection
#
# >      UkSidebarSection (items, header=None, cls='', **kwargs)

# %%
#| echo: false
#| output: asis
show_doc(UkSidebarUl)
# Out:
# ---
#
# [source](https://github.com/Isaac-Flath/fh-frankenui/blob/main/fh_frankenui/core.py#L367){target="_blank" style="float:right; font-size:smaller"}
#
# ### UkSidebarUl
#
# >      UkSidebarUl (*lis, cls='space-y-2', **kwargs)

# %%
#| echo: false
#| output: asis
show_doc(UkSidebarItem)
# Out:
# ---
#
# [source](https://github.com/Isaac-Flath/fh-frankenui/blob/main/fh_frankenui/core.py#L364){target="_blank" style="float:right; font-size:smaller"}
#
# ### UkSidebarItem
#
# >      UkSidebarItem (item, is_header=False)

# %% [markdown]
# ### Cards

# %%
#| echo: false
#| output: asis
show_doc(Card)
# Out:
# ---
#
# [source](https://github.com/Isaac-Flath/fh-frankenui/blob/main/fh_frankenui/core.py#L382){target="_blank" style="float:right; font-size:smaller"}
#
# ### Card
#
# >      Card (*c, header=None, footer=None, body_cls='space-y-6', header_cls=(),
# >            footer_cls=(), cls=(), **kwargs)

# %% [markdown]
# ### Modals

# %%
#| echo: false
#| output: asis
show_doc(Modal)
# Out:
# ---
#
# [source](https://github.com/Isaac-Flath/fh-frankenui/blob/main/fh_frankenui/core.py#L401){target="_blank" style="float:right; font-size:smaller"}
#
# ### Modal
#
# >      Modal (*c, header=None, footer=None, body_cls='space-y-6',
# >             header_cls='p-6', footer_cls=(), cls=(), **kwargs)

# %%
#| echo: false
#| output: asis
show_doc(UkModalTitle)
# Out:
# ---
#
# [source](https://github.com/Isaac-Flath/fh-frankenui/blob/main/fh_frankenui/core.py#L399){target="_blank" style="float:right; font-size:smaller"}
#
# ### UkModalTitle
#
# >      UkModalTitle (*c, cls=())

# %% [markdown]
# ### Tables

# %%
#| echo: false
#| output: asis
show_doc(TableHeader)
# Out:
# ---
#
# ### TableHeader
#
# >      TableHeader (columns, header_render=None)

# %%
#| echo: false
#| output: asis
show_doc(TableRow)
# Out:
# ---
#
# ### TableRow
#
# >      TableRow (row, columns, cell_render=None)

# %%
#| echo: false
#| output: asis
show_doc(UkTable)
# Out:
# ---
#
# [source](https://github.com/Isaac-Flath/fh-frankenui/blob/main/fh_frankenui/core.py#L432){target="_blank" style="float:right; font-size:smaller"}
#
# ### UkTable
#
# >      UkTable (columns, data, *args, cls=(), footer=None, cell_render=None,
# >               header_render=None, **kwargs)

# %% [markdown]
# ### Forms

# %%
#| echo: false
#| output: asis
show_doc(UkFormSection)
# Out:
# ---
#
# [source](https://github.com/Isaac-Flath/fh-frankenui/blob/main/fh_frankenui/core.py#L440){target="_blank" style="float:right; font-size:smaller"}
#
# ### UkFormSection
#
# >      UkFormSection (title, description, *c, button_txt='Update',
# >                     outer_margin=6, inner_margin=6)
