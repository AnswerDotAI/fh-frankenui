# %% [raw]
# ---
# description: Components that are the building blocks to the UI
# output-file: components.html
# title: Components
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# ## Imports

# %%
from nbdev.showdoc import show_doc
from IPython.display import HTML

# %%
#| echo: false
#| output: asis
show_doc(NavP)
# Out:
# ---
#
# [source](https://github.com/Isaac-Flath/fh-frankenui/blob/main/fh_frankenui/components.py#L18){target="_blank" style="float:right; font-size:smaller"}
#
# ### NavP
#
# >      NavP (*c, cls=<TextT.muted_sm: (<TextB.sz_small: 'text-sm'>,
# >            <TextB.cl_muted: 'uk-text-muted'>)>)

# %%
#| echo: false
#| output: asis
show_doc(SpacedPP)
# Out:
# ---
#
# [source](https://github.com/Isaac-Flath/fh-frankenui/blob/main/fh_frankenui/components.py#L21){target="_blank" style="float:right; font-size:smaller"}
#
# ### SpacedPP
#
# >      SpacedPP (left, right=None)

# %%
#| echo: false
#| output: asis
show_doc(SpacedPPs)
# Out:
# ---
#
# [source](https://github.com/Isaac-Flath/fh-frankenui/blob/main/fh_frankenui/components.py#L24){target="_blank" style="float:right; font-size:smaller"}
#
# ### SpacedPPs
#
# >      SpacedPPs (*c)

# %%
#| echo: false
#| output: asis
show_doc(SpacedTxtIcon)
# Out:
# ---
#
# [source](https://github.com/Isaac-Flath/fh-frankenui/blob/main/fh_frankenui/components.py#L27){target="_blank" style="float:right; font-size:smaller"}
#
# ### SpacedTxtIcon
#
# >      SpacedTxtIcon (txt, icon, ratio, icon_right=True)

# %%
#| echo: false
#| output: asis
show_doc(LAlignedTxtIcon)
# Out:
# ---
#
# [source](https://github.com/Isaac-Flath/fh-frankenui/blob/main/fh_frankenui/components.py#L33){target="_blank" style="float:right; font-size:smaller"}
#
# ### LAlignedTxtIcon
#
# >      LAlignedTxtIcon (txt, icon='play-circle', cls='space-x-2', ratio=1,
# >                       icon_right=True, txt_cls=None)

# %%
#| echo: false
#| output: asis
show_doc(LAlignedIconTxt)
# Out:
# ---
#
# [source](https://github.com/Isaac-Flath/fh-frankenui/blob/main/fh_frankenui/components.py#L40){target="_blank" style="float:right; font-size:smaller"}
#
# ### LAlignedIconTxt
#
# >      LAlignedIconTxt (txt, icon, cls='space-x-2', ratio=1, txt_cls=None)

# %% [markdown]
# ## Fonts

# %%
#| echo: false
#| output: asis
show_doc(HelpText)
# Out:
# ---
#
# [source](https://github.com/Isaac-Flath/fh-frankenui/blob/main/fh_frankenui/components.py#L45){target="_blank" style="float:right; font-size:smaller"}
#
# ### HelpText
#
# >      HelpText (c)

# %% [markdown]
# What are better names for [`HelpText`](https://Isaac-Flath.github.io/fh-frankenui/components.html#helptext), which is basically like a font.  I want it to be searchable based on what it can be used for.  It's a small muted font that works well is nav dropdowns, help text on forms, descriptions of headings, etc.
